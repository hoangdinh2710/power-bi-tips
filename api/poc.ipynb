# %%
from all_functions import get_dataset_users, get_header

# %%
header = get_header()

a = get_dataset_users(header,'07e58b6b-c3ce-4c8b-9c82-629b458a33e2','7dd09a9b-46bb-426f-ba7a-8f48493f12c4')
# Out:
# Get dataset users 7dd09a9b-46bb-426f-ba7a-8f48493f12c4

# %%
a
# Out:
#      datasetUserAccessRight                            identifier  \
# 0   ReadWriteReshareExplore               Jenee.Stewart@lumen.com
# 1                      Read                 John.Hillis@lumen.com
# 2                      Read                  Jeff.Dunn2@lumen.com
# 3                      Read                Neal.Krenski@lumen.com
# 4                      Read   Remith.ThuvakkunnonPonnon@lumen.com
# 5                      Read           Manjunath.Karanth@lumen.com
# 6                      Read              Tony.Ronquillo@lumen.com
# 7   ReadWriteReshareExplore          Michael.Mulholland@lumen.com
# 8   ReadWriteReshareExplore                   Paul.Ward@lumen.com
# 9                      Read                 David.Platt@lumen.com
# 10                     Read             Kathryn.Warren1@lumen.com
# 11                     Read               Jason.Krewson@lumen.com
# 12                     Read             Paul.Piantanida@lumen.com
# 13                     Read                  roger.fong@lumen.com
# 14                     Read             Mercedes.Miller@lumen.com
# 15                     Read              Brian.P.Ho-Yen@lumen.com
# 16                     Read                Suzanne.Webb@lumen.com
# 17                     Read             Anup.Srivastava@lumen.com
# 18                     Read            Lupita.Gutierrez@lumen.com
# 19  ReadWriteReshareExplore              Miranda.Markel@lumen.com
# 20  ReadWriteReshareExplore               Nick.Swekosky@lumen.com
# 21  ReadWriteReshareExplore                    Joe.Bear@lumen.com
# 22  ReadWriteReshareExplore                  Hoang.Dinh@lumen.com
# 23  ReadWriteReshareExplore                Brian.Gadson@lumen.com
# 24  ReadWriteReshareExplore               Kelly.Hoffman@lumen.com
# 25  ReadWriteReshareExplore                 Ryan.Porter@lumen.com
# 26  ReadWriteReshareExplore  5bd74192-3e18-402e-a20a-7b4e45956b56
# 27  ReadWriteReshareExplore  07e58b6b-c3ce-4c8b-9c82-629b458a33e2
# 28  ReadWriteReshareExplore  3ad0a134-15ea-4acf-96a1-8656f3f9cf00
# 29  ReadWriteReshareExplore  5a14bdf0-fd2a-48c8-a7fc-7499f4bb2d98
# 30                     Read  005b1e96-c9b6-4818-ad81-89fcc0e6c877
# 31  ReadWriteReshareExplore  3362adca-82c6-48c2-8944-fffa757c32b7
#
#    principalType
# 0           User
# 1           User
# 2           User
# 3           User
# 4           User
# 5           User
# 6           User
# 7           User
# 8           User
# 9           User
# 10          User
# 11          User
# 12          User
# 13          User
# 14          User
# 15          User
# 16          User
# 17          User
# 18          User
# 19          User
# 20          User
# 21          User
# 22          User
# 23          User
# 24          User
# 25          User
# 26           App
# 27         Group
# 28         Group
# 29         Group
# 30         Group
# 31         Group
